# %%
import networkx as nx
import pandas as pd

# %%
G = nx.random_geometric_graph(100, 0.15, seed=43)

for i in range(99):
    if G.has_edge(i, 99):
        G.remove_edge(i, 99)

for i in range(99):
    G.add_edge(i, i+99)

print(list(G.neighbors(197)))

nx.draw(G, with_labels=True)
a = nx.adjacency_matrix(G)
from scipy.sparse import csr_matrix, find
find(a)
adj = []
for i in range(198):
    for j in a[[i], :]:
        adj.append(j.toarray()[0])
# Out:
# [98]

# %%
pd.DataFrame(adj).to_csv("99_sybil.csv", index=None)

# %%
import pandas as pd 
adj =pd.read_csv("100.csv").values.tolist()

# %%
print(min(list(map(lambda x: sum(x), adj[:99]))))
print(list(map(lambda x: sum(x), adj[:99])).index(3))
# Out:
# 3
# 38

# %%
adj[0][9]
# Out:
# 1

# %%
G = nx.watts_strogatz_graph(100, 4, 0.9, seed=42)
nx.draw(G, with_labels=True)
a = nx.adjacency_matrix(G)
from scipy.sparse import csr_matrix, find
find(a)
adj = []
for i in range(100):
    for j in a[[i], :]:
        adj.append(j.toarray()[0])

# %%
print(max(list(map(lambda x: sum(x), adj))))
# Out:
# 8

# %%
G = nx.random_geometric_graph(5, 0.4, seed=43)


for i in range(4):
    if G.has_edge(i, 4):
        G.remove_edge(i, 4)

for i in range(4):
    G.add_edge(i, i+4)

nx.draw(G, with_labels=True)

# %%
a = nx.adjacency_matrix(G)
from scipy.sparse import csr_matrix, find
find(a)
adj = []
for i in range(8):
    for j in a[[i], :]:
        adj.append(j.toarray()[0])
adj
# Out:
# [array([0, 1, 0, 0, 1, 0, 0, 0]),
#  array([1, 0, 0, 1, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0, 1, 0]),
#  array([0, 1, 1, 0, 0, 0, 0, 1]),
#  array([1, 0, 0, 0, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0, 0, 0]),
#  array([0, 0, 1, 0, 0, 0, 0, 0]),
#  array([0, 0, 0, 1, 0, 0, 0, 0])]

# %%
pd.DataFrame(adj).to_csv("4_sybil.csv", index=None)

# %%
G = nx
