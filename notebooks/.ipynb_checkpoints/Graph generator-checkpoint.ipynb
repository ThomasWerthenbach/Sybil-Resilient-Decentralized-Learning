# %%
import networkx as nx
import pandas as pd

# %%
G = nx.random_geometric_graph(100, 0.15, seed=43)

for i in range(99):
    if G.has_edge(i, 99):
        G.remove_edge(i, 99)

for i in range(99):
    G.add_edge(i, i+99)

print(list(G.neighbors(100)))

nx.draw(G, with_labels=True)
a = nx.adjacency_matrix(G)
from scipy.sparse import csr_matrix, find
find(a)
adj = []
for i in range(100):
    for j in a[[i], :]:
        adj.append(j.toarray()[0])
# Out:
# [1]

# %%
pd.DataFrame(adj).to_csv("100_sybil.csv", index=None)

# %%
import pandas as pd 
adj =pd.read_csv("100.csv").values.tolist()

# %%
print(max(list(map(lambda x: sum(x), adj))))
# Out:
# 10

# %%
adj[0][9]
# Out:
# 1

# %%
G = nx.watts_strogatz_graph(100, 4, 0.9, seed=42)
nx.draw(G, with_labels=True)
a = nx.adjacency_matrix(G)
from scipy.sparse import csr_matrix, find
find(a)
adj = []
for i in range(100):
    for j in a[[i], :]:
        adj.append(j.toarray()[0])

# %%
print(max(list(map(lambda x: sum(x), adj))))
# Out:
# 8
