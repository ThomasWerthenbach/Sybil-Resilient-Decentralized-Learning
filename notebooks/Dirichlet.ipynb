# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Out:
# array([[9.99800126e-01, 1.99873843e-04],
#        [1.52740338e-01, 8.47259662e-01],
#        [9.99987708e-01, 1.22915783e-05],
#        [2.18439241e-04, 9.99781561e-01],
#        [3.52454107e-01, 6.47545893e-01],
#        [9.62776885e-04, 9.99037223e-01],
#        [9.99999998e-01, 1.50120999e-09],
#        [6.64142016e-02, 9.33585798e-01],
#        [7.50680291e-01, 2.49319709e-01],
#        [9.92653432e-01, 7.34656764e-03]])

# %%
s = np.random.dirichlet([0.1] * 10, 10)
print(s)
plt.barh(range(10), s[:, 0])
plt.barh(range(10), s[:, 1], left=s[:, 0], color='g')
plt.barh(range(10), s[:, 2], left=s[:, 0]+s[:, 1], color='r')
plt.title("Lengths of Strings")
# Out:
# [[9.55358516e-03 6.39520808e-01 7.18228013e-04 2.67451831e-01
#   1.14970949e-02 2.81093659e-06 7.03551535e-02 5.31010147e-07
#   8.78472039e-04 2.14855595e-05]
#  [2.41181421e-01 1.25553989e-05 8.92132288e-11 7.56423263e-01
#   1.48676006e-08 4.98540906e-25 2.34538964e-05 4.96577394e-10
#   2.35860459e-03 6.86065078e-07]
#  [7.27494333e-02 4.05265150e-01 3.57284569e-02 1.88894057e-06
#   1.85556974e-08 8.07721616e-04 2.31233578e-04 3.39949195e-01
#   4.12061443e-10 1.45266902e-01]
#  [8.27638769e-01 6.56019435e-03 6.11530436e-05 1.57239669e-02
#   5.35615462e-09 6.88610592e-04 2.80319372e-08 4.63101699e-02
#   1.03016532e-01 5.70769466e-07]
#  [4.34958577e-01 3.92955240e-05 2.36103757e-01 1.85706580e-02
#   1.05666921e-04 2.80997847e-01 2.11100901e-04 2.68409101e-02
#   2.17218722e-03 1.91560564e-10]
#  [2.40296957e-08 5.34701815e-01 4.16406620e-05 4.25642526e-01
#   1.33991981e-02 2.40782776e-05 2.96677790e-07 1.07602232e-11
#   2.29436622e-25 2.61904214e-02]
# ...

# %%
np.random.seed(42)
s = np.random.dirichlet([0.1] * 10, 10).transpose()
print(s)
plt.barh(range(10), s[0])
plt.barh(range(10), s[1], left=s[0])
plt.barh(range(10), s[2], left=s[0]+s[1])
plt.barh(range(10), s[3], left=s[0]+s[1]+s[2])
plt.barh(range(10), s[4], left=s[0]+s[1]+s[2]+s[3])
plt.barh(range(10), s[5], left=s[0]+s[1]+s[2]+s[3]+s[4])
plt.barh(range(10), s[6], left=s[0]+s[1]+s[2]+s[3]+s[4]+s[5])
plt.barh(range(10), s[7], left=s[0]+s[1]+s[2]+s[3]+s[4]+s[5]+s[6])
plt.barh(range(10), s[8], left=s[0]+s[1]+s[2]+s[3]+s[4]+s[5]+s[6]+s[7])
plt.barh(range(10), s[9], left=s[0]+s[1]+s[2]+s[3]+s[4]+s[5]+s[6]+s[7]+s[8])
plt.title("Lengths of Strings")
# Out:
# [[2.58189613e-04 6.60899302e-03 4.03519091e-10 2.35591663e-04
#   3.20843601e-01 8.75991283e-16 6.03168000e-06 2.47828818e-02
#   9.45934029e-06 2.43636904e-03]
#  [2.09908582e-01 4.07046905e-06 1.27362010e-15 4.57549640e-01
#   2.20093251e-05 8.77780189e-06 2.15890189e-07 9.42831853e-05
#   1.04169820e-14 6.86237559e-11]
#  [4.06181574e-08 3.49929058e-04 7.41671667e-07 9.16894078e-06
#   1.18310147e-05 1.26200566e-04 7.65122665e-02 1.89938245e-01
#   1.01689480e-03 4.91241160e-01]
#  [2.07726305e-12 9.05473085e-08 4.76899927e-06 9.24963959e-09
#   5.97791874e-02 3.66179372e-07 1.50417655e-22 3.50507223e-12
#   1.02458400e-02 2.81337214e-05]
#  [2.92773029e-02 4.78544584e-03 1.31364286e-03 1.58775042e-11
#   4.22612837e-01 3.88530145e-06 9.15711285e-05 1.09382311e-07
#   2.03318210e-02 5.70098151e-02]
#  [6.49168365e-17 6.15812577e-03 6.64877113e-01 2.25848918e-01
#   8.37081659e-10 4.76851302e-01 3.49186015e-10 5.04644546e-01
#   4.69536594e-01 4.23163200e-01]
# ...

# %%
np.random.seed(42)
num_peers = 100
s = np.random.dirichlet([0.01] * num_peers, 10)
# print(s)
for first in s.transpose():
    print(max(first) * 60000/10)
#     a =""
#     for second in first:
#         a += str(round(float(second) * 60000/10, 1)) + "\t"
#     print(a)
        
# s = np.array([[1.07828757e-03,8.76649576e-01,1.69635230e-07,8.67535647e-12,1.22271967e-01]
# ,[8.53544596e-17,9.98544398e-01,2.46808081e-07,4.24638472e-05,1.41289177e-03]
# ,[5.62537919e-01,3.46466274e-04,2.97849254e-02,7.70711882e-06,4.07322982e-01]
# ,[6.23133479e-03,1.23417571e-12,9.73305597e-01,6.25594523e-06,2.04568124e-02]
# ,[3.05892346e-07,9.65482551e-13,5.62232844e-04,3.61519544e-03,9.95822266e-01]
# ,[6.65755347e-01,3.31025337e-01,3.21931573e-03,1.62383889e-11,1.97462097e-14]
# ,[5.14623284e-04,9.99465328e-01,2.00285119e-05,2.02047893e-08,3.46826083e-11]
# ,[4.16537420e-01,1.45599675e-22,1.71957853e-01,4.11311272e-01,1.93455320e-04]
# ,[3.99422130e-01,2.73996785e-05,1.47285751e-05,7.44198428e-02,5.26115899e-01]
# ,[4.25496563e-09,4.61756373e-01,5.27414558e-01,1.08290652e-02,8.00570299e-16]])
# print(s)
plt.barh(range(num_peers), s[0])
plt.barh(range(num_peers), s[1], left=s[0])
plt.barh(range(num_peers), s[2], left=s[0]+s[1])
plt.barh(range(num_peers), s[3], left=s[0]+s[1]+s[2])
plt.barh(range(num_peers), s[4], left=s[0]+s[1]+s[2]+s[3])
plt.barh(range(num_peers), s[5], left=s[0]+s[1]+s[2]+s[3]+s[4])
plt.barh(range(num_peers), s[6], left=s[0]+s[1]+s[2]+s[3]+s[4]+s[5])
plt.barh(range(num_peers), s[7], left=s[0]+s[1]+s[2]+s[3]+s[4]+s[5]+s[6])
plt.barh(range(num_peers), s[8], left=s[0]+s[1]+s[2]+s[3]+s[4]+s[5]+s[6]+s[7])
plt.barh(range(num_peers), s[9], left=s[0]+s[1]+s[2]+s[3]+s[4]+s[5]+s[6]+s[7]+s[8])
plt.title("Lengths of Strings")
# Out:
# 0.00873337342320153
# 9.549620778607624e-07
# 15.638389255930047
# 1933.3037716493607
# 3013.443061281315
# 6.549160316125838
# 24.37100952700079
# 2.1261297323193797e-11
# 69.93073314348374
# 3467.1074937467624
# 220.51013789607038
# 6.694436808128485
# 2144.7213099219925
# 759.3028747187157
# 1505.1783219959
# 1.2446963046797205e-06
# 0.005037623454472505
# 627.7193896259447
# 0.008241161526192056
# 0.010252284919917908
# 25.271289910039812
# 44.666107211845
# 2.8290153085389647
# 942.9840753054735
# 287.89850090917946
# 802.2723367820664
# 3682.430074353554
# 1442.2515779881182
# 15.974436844452262
# 1323.5145300303132
# 0.013003211423104007
# 0.0022070935569376794
# 81.6699342483665
# 0.004812453290551344
# 7.2008704067115165e-06
# 7.636522105447932e-06
# 602.2074976023257
# 4.286076238320306e-11
# 5586.121613763971
# 170.88379849647953
# 0.10184066862344832
# 81.80848234106607
# 4.138769722455804e-15
# 5.689456777352788
# 71.9170066506241
# 95.22007345471226
# ...
